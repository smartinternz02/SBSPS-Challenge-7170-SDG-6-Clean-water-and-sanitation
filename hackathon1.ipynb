# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TSIC/Sanitation.csv')

# %%
print(df)
# Out:
#          ULB Name  ...  Garbage lifted/day (Mts)
# 0        Adilabad  ...                      64.0
# 1   Andol-Jogipet  ...                       3.9
# 2          Armoor  ...                      30.0
# 3       Atchampet  ...                      14.0
# 4       Badangpet  ...                      28.0
# ..            ...  ...                       ...
# 67      Vikarabad  ...                      25.0
# 68     Wanaparthy  ...                      32.0
# 69       Warangal  ...                       0.0
# 70       Yellandu  ...                      30.0
# 71     Zaheerabad  ...                      32.0
#
# [72 rows x 20 columns]

# %%
df.isna().sum()
# Out:
# ULB Name                                    0
# Public Toilets                             41
# Community Toilets                          59
# She Toilets                                62
# ODF Declared Wards                          0
# ODF Non Declared Wards                      0
# Compost Yard Location & Extent (Acrs)       0
# Dry Resourse Collection Center (Yes/No)    12
# % of Door to Door Collection                0
# Tractors                                    0
# Autos                                       0
# Tricycles                                   0
# Pushcarts                                   0
# Regular Workers                             0
# Out Sourced Workers                         0
# Government Hospitals                        0
# Private Hospitals                           0
# Urban Health Centres                        0
# Garbage generation/day (Mts)                0
# Garbage lifted/day (Mts)                    0
# dtype: int64

# %%
na_counts = df.isna().sum()
base_color = sns.color_palette()[0]
sns.barplot(na_counts.index.values, na_counts, color = base_color)
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.pop("She Toilets")
df
# Out:
#          ULB Name  ...  Garbage lifted/day (Mts)
# 0        Adilabad  ...                      64.0
# 1   Andol-Jogipet  ...                       3.9
# 2          Armoor  ...                      30.0
# 3       Atchampet  ...                      14.0
# 4       Badangpet  ...                      28.0
# ..            ...  ...                       ...
# 67      Vikarabad  ...                      25.0
# 68     Wanaparthy  ...                      32.0
# 69       Warangal  ...                       0.0
# 70       Yellandu  ...                      30.0
# 71     Zaheerabad  ...                      32.0
#
# [72 rows x 19 columns]

# %%
df=df.fillna(method='ffill',axis=0)
df
# Out:
#          ULB Name  ...  Garbage lifted/day (Mts)
# 0        Adilabad  ...                      64.0
# 1   Andol-Jogipet  ...                       3.9
# 2          Armoor  ...                      30.0
# 3       Atchampet  ...                      14.0
# 4       Badangpet  ...                      28.0
# ..            ...  ...                       ...
# 67      Vikarabad  ...                      25.0
# 68     Wanaparthy  ...                      32.0
# 69       Warangal  ...                       0.0
# 70       Yellandu  ...                      30.0
# 71     Zaheerabad  ...                      32.0
#
# [72 rows x 19 columns]

# %%
df=df.fillna(method='ffill',axis=1)
df
# Out:
#          ULB Name  ... Garbage lifted/day (Mts)
# 0        Adilabad  ...                       64
# 1   Andol-Jogipet  ...                      3.9
# 2          Armoor  ...                       30
# 3       Atchampet  ...                       14
# 4       Badangpet  ...                       28
# ..            ...  ...                      ...
# 67      Vikarabad  ...                       25
# 68     Wanaparthy  ...                       32
# 69       Warangal  ...                        0
# 70       Yellandu  ...                       30
# 71     Zaheerabad  ...                       32
#
# [72 rows x 19 columns]

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
sns.lineplot(data = df, x = 'Garbage generation/day (Mts)', y = 'Garbage lifted/day (Mts)')
